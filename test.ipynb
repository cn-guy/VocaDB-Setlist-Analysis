# %% [markdown]
# ## This should be a markdown section

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # Another Markdown Section

# %%
import pandas as pd
import json

songs_df = pd.read_json("vocaloid_setlist_songs.json")
songs_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2274 entries, 0 to 2273
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              2274 non-null   str
#  1   english_title      2274 non-null   str
#  2   artist             2274 non-null   str
#  3   length_seconds     2274 non-null   int64
#  4   setlist_frequency  2274 non-null   int64
#  5   avg_setlist_order  2274 non-null   float64
#  6   song_type          2274 non-null   str
#  7   pv_services        2274 non-null   str
#  8   times_favorited    2274 non-null   int64
#  9   rating             2274 non-null   int64
# dtypes: float64(1), int64(4), str(5)
# memory usage: 177.8 KB

# %%
songs_df.describe()
# Out:
#        length_seconds  setlist_frequency  avg_setlist_order  times_favorited  \
# count     2274.000000        2274.000000        2274.000000      2274.000000
# mean       221.119173           2.375110          14.552881        27.866755
# std         93.778410           4.140145          12.440373        54.097615
# min          0.000000           1.000000           1.000000         0.000000
# 25%        196.000000           1.000000           6.250000         1.000000
# 50%        227.000000           1.000000          11.750000         6.000000
# 75%        260.000000           2.000000          18.500000        27.750000
# max       2304.000000          75.000000          93.000000       648.000000
#
#             rating
# count  2274.000000
# mean    152.606860
# std     273.224306
# min       0.000000
# 25%       9.000000
# 50%      39.000000
# 75%     165.000000
# max    2985.000000

# %%
songs_df.head(10)
# Out:
#                             title                            english_title  \
# 0                       STARLIGHT                                     None
# 1  Love is in Trouble -恋愛主義バージョン-                                     None
# 2          HEADSTRONG -恋愛主義バージョン-        HEADSTRONG -Renai Shugi Version--
# 3                精神疾患 -恋愛主義バージョン-   Mental Illness -Love Doctrine Version-
# 4               愛をつかむ -恋愛主義バージョン-     Ai wo Tsukamu -Renai Shugi Version-
# 5                          物語の始まり                   Monogatari no Hajimari
# 6           CAFETERIA -恋愛主義バージョン-                                     None
# 7            My Lover -恋愛主義バージョン-           My Lover -Renai Shugi Version-
# 8             許してください -恋愛主義バージョン-  Yurushite Kudasai -Renai Shugi Version-
# 9                        ビーチストーリー                              Beach Story
#
#                          artist  length_seconds  setlist_frequency  \
# 0                失いP feat. 花隈千冬               0                  1
# ...

# %%
mask = songs_df["setlist_frequency"] > 20

frequent_songs = songs_df[songs_df["setlist_frequency"] > 30]
frequent_songs
# Out:
#                title               english_title  \
# 64               千本桜  A Thousand Cherry Blossoms
# 73     ルカルカ★ナイトフィーバー       Luka Luka★Night Fever
# 83               メルト                        Melt
# 149             リモコン              Remote Control
# 152        ワールドイズマイン               World is Mine
# 188              ???                        None
# 268  Tell Your World                        None
#
#                                              artist  length_seconds  \
# 64                                  黒うさP feat. 初音ミク             246
# 73                               samfree feat. 巡音ルカ             239
# 83                                   ryo feat. 初音ミク             256
# 149  じーざすP, WONDERFUL★OPPORTUNITY! feat. 鏡音リン, 鏡音レン             312
# 152                       ryo, supercell feat. 初音ミク             255
# 188                                                               0
# 268                                   kz feat. 初音ミク             257
#
# ...

# %%
songs_df.sort_values(by="rating", ascending=False).head(10)
# Out:
#                title               english_title  \
# 123          ローリンガール                Rollin' Girl
# 96              炉心融解                    Meltdown
# 1412          マトリョシカ                  Matryoshka
# 97          ロストワンの号哭          Lost One's Weeping
# 74    ワールズエンド・ダンスホール       World's End Dancehall
# 64               千本桜  A Thousand Cherry Blossoms
# 945             恋は戦争               Koi wa Sensou
# 80         ロミオとシンデレラ        Romeo and Cinderella
# 370             ヒビカセ                    Resonate
# 152        ワールドイズマイン               World is Mine
#
#                               artist  length_seconds  setlist_frequency  \
# 123                wowaka feat. 初音ミク             196                 22
# 96          iroha(sasaki) feat. 鏡音リン             333                 15
# 1412             ハチ feat. 初音ミク, GUMI             201                  6
# 97    Neru feat. 鏡音リン Append (Power)             217                  8
# ...

# %%
songs_df.sort_values(by = "length_seconds", ascending=True).head(10)
# Out:
#                       title  \
# 0                 STARLIGHT
# 5                    物語の始まり
# 9                  ビーチストーリー
# 10                    黒いメガネ
# 11                      僕の命
# 12              うさぎ小さいを食べたい
# 13                    前を向いて
# 1886                歌うPower
# 1932                  さくらんぼ
# 1863  ずんだもんと東北三姉妹のカレーうどん狂騒曲
#
#                                           english_title  \
# 0                                                  None
# 5                                Monogatari no Hajimari
# 9                                           Beach Story
# 10                                         Kuroi Megane
# 11                                       Boku no Inochi
# 12                               Usagi Chisai o Tabetai
# 13                                                 None
# 1886                                               None
# 1932                                          Sakuranbo
# 1863  Zundamon to Touhoku San Shimai no Curry Udon K...
#
# ...

# %%
songs_df_clean = songs_df.query("length_seconds != 0")
songs_df_clean.sort_values(by="length_seconds", ascending = True).head(10)
# Out:
# <class 'pandas.DataFrame'>
# Index: 2143 entries, 1 to 2273
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              2143 non-null   str
#  1   english_title      2143 non-null   str
#  2   artist             2143 non-null   str
#  3   length_seconds     2143 non-null   int64
#  4   setlist_frequency  2143 non-null   int64
#  5   avg_setlist_order  2143 non-null   float64
#  6   song_type          2143 non-null   str
#  7   pv_services        2143 non-null   str
#  8   times_favorited    2143 non-null   int64
#  9   rating             2143 non-null   int64
# dtypes: float64(1), int64(4), str(5)
# memory usage: 184.2 KB

# %%
songs_df_clean = songs_df_clean.query("pv_services != 'Nothing'")
songs_df_clean.sort_values(by="rating", ascending=True).head(10)
# Out:
# <class 'pandas.DataFrame'>
# Index: 2090 entries, 1 to 2273
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              2090 non-null   str
#  1   english_title      2090 non-null   str
#  2   artist             2090 non-null   str
#  3   length_seconds     2090 non-null   int64
#  4   setlist_frequency  2090 non-null   int64
#  5   avg_setlist_order  2090 non-null   float64
#  6   song_type          2090 non-null   str
#  7   pv_services        2090 non-null   str
#  8   times_favorited    2090 non-null   int64
#  9   rating             2090 non-null   int64
# dtypes: float64(1), int64(4), str(5)
# memory usage: 179.6 KB

# %%
songs_df_clean = songs_df_clean.query("avg_setlist_order < 1000")
songs_df_clean = songs_df_clean.query("setlist_frequency > 5")
songs_df_clean.sort_values(by="avg_setlist_order", ascending=True)
songs_df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 184 entries, 55 to 1412
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              184 non-null    str
#  1   english_title      184 non-null    str
#  2   artist             184 non-null    str
#  3   length_seconds     184 non-null    int64
#  4   setlist_frequency  184 non-null    int64
#  5   avg_setlist_order  184 non-null    float64
#  6   song_type          184 non-null    str
#  7   pv_services        184 non-null    str
#  8   times_favorited    184 non-null    int64
#  9   rating             184 non-null    int64
# dtypes: float64(1), int64(4), str(5)
# memory usage: 15.8 KB
